# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasAT08/MineriadeDatos/blob/main/TallerAsociaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Por cada un de las siguientes preguntas, proveer un ejemplo de una regla de asociación del dominio de “market basket” que satisface las siguientes condiciones. También, describir si las reglas son interesantes (subjetivamente).**
#
# **Nota:** El data set fue cargado en el software *Weka* y se excluyó el ID de las transacciones.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***a) Una regla que que tiene alto soporte y alta confianza.***
#
# ***RESPUESTA:*** el máximo soporte es de 50% al probar con diferentes valores, por lo tanto este es máximo soporte posible. Se ajusto una confianza del 100%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***b) Una regla que tiene razonablemente alto soporte pero baja confianza.***
# ***RESPUESTA:*** considerando que el soporte máximo posible es de 50%, se establece un valor de 44% y una confianza de 20%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***c) Una regla que tiene bajo soporte y baja confianza.***
# ***RESPUESTA:*** se define soporte y confianza de 20%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***d) Una regla que tiene bajo soporte y alta confianza.***
# ***RESPUESTA:*** se define soporte de 20% y confianza de 95%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***2. ¿Por qué el proceso de descubrimiento de reglas de asociación es relativamente simple comparado con la generación de grandes conjuntos de ítems en bases de datos transaccionales?***
# ***RESPUESTA:*** esto puede ser generado por la facilidad que brindan los algoritmos de poda para minimizar los cálculos innecesarios y minimizar el costo computacional como lo es la poda por medio de itemsets frecuentes. Sumado a lo anterior, algorimos como el "Apriori" facilitan la generación de reglas.
#
# Por otra parte, las bases transaccionales deben contener todos los registros/objetos que se generan en grandes cantidades y periodos de tiempo sumamente cortos (minutos). De allí una mayor complejidad en comparación con el proceso de descubrimiento de reglas de asociación.

# %% [markdown]
# # ***3. Considere el siguiente conjunto de datos:***
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Nota:** el conunto de datos fue cargado en Weka. Sus valores fueron asociados a los diferentes items como columnas y su existencia o ausencia (true,false) respectivamente.
#
# ## ***a) ¿cuál es el número máximo de reglas de asociación que se pueden generar? (incluyendo reglas con soporte 0).***
#
# ***RESPUESTA:*** hay dos posibilidades para hallar el núero de reglas con soporte cercano a cero: (i) Alta confianza, y (ii) Baja confianza.
#
# (i) Al definir el soporte y confianza con un valor de 10% (ajustado a este valor por Weka al ingresar min_soporte de $0$%) y una confianza de 95%, se obtienen 12 reglas de asociación.
#
# (ii) Al definir el soporte y confianza con un valor de 10% (ajustado a este valor por Weka al ingresar min_soporte de $0$%) y una confianza de 10%, se obtienen 88 reglas de asociación.

# %% [markdown]
# **(i)**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **(ii)**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***b) ¿cuál es el tamaño máximo de los conjuntos de items frecuentes que se pueden extraer (asumir el umbral de minsoporte > 0)?***
#
# ***RESPUESTA:*** hay dos posibilidades para hallar el núero de reglas con soporte cercano a cero: (i) Alta confianza, y (ii) Baja confianza.
#
# (i) Al definir el soporte y confianza con un valor de 10% (ajustado a este valor por Weka al ingresar min_soporte de $0$%) y una confianza de 95%, se obtieneun conjunto máximo de 4 items.
#
# (ii) Al definir el soporte y confianza con un valor de 10% (ajustado a este valor por Weka al ingresar min_soporte de $0$%) y una confianza de 10%, se obtiene un conjunto máximo de 4 items.

# %% [markdown]
# **(i)**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **(ii)**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***c) Escribir una regla que contenga 3 ítems que se genere de este conjunto de datos.***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***d) Encontrar un conjunto de items (de tamaño mayor a 2) con el valor de soporte máximo.***
#
# ***RESPUESTA:*** soporte máximo es de 50%. no se encontró un itemset mayor a 2, incluso definiendo confianza de 0%.

# %% [markdown]
# ## ***e) Encontrar un par de ítems (a y b) tal que las reglas a → b y b → a tengan la misma confianza.***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***4. Dado la siguiente base de datos X:***
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Usando valores de umbral de soporte = 25 % y confianza = 60 %, encuentre:
#
# ## ***a) Todos los conjuntos de ítems en la base de datos X.***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***b) Reglas de asociación fuertes para la base de datos X.***
#
# ***RESPUESTA:*** se consideran reglas fuertes aquellas que presentan una confianza relativamente alta. Por lo tanto se listan las reglas con 100-80% de confianza.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***c) Analice las asociaciones engañosas para el conjunto de reglas obtenido en el numeral anterior.***
#
# ***RESPUESTA:***

# %% [markdown]
# # ***5. El algoritmo Apriori usa estrategías de generación y conteo para derivar conjuntos de items frecuentes. Conjuntos de item de tamaño k + 1 son creados de conjuntos de items de tamaño k. Un conjunto candidato es eliminado si uno de sus subconjuntos no es frecuente en la fase de poda. Supongamos que el algoritmo Apriori es aplicado a los datos de la siguiente tabla con un soporte mínimo de 30% (ejercicio realizado en clase).***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***a) Dibujar el lattice de los conjuntos de items y etiquetar cada nodo con las siguientes letras:***
#
# **i.**   N: si el conjunto no es considerado candidato.
#
# **ii.**  F: si el conjunto candidato es frecuente.
#
# **iii.** I: si el conjunto candidato no es frecuente.
#
# En seguida se muestran las diferentes corridas a o largo de la estructura *Lattice*.

# %% [markdown]
# **ITEMSETS TAMAÑO 1**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ITEMSETS TAMAÑO 2**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ITEMSETS TAMAÑO 3**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***b) ¿Cuál es el porcentaje de conjuntos de items frecuente?***
#
# ***RESPUESTA:*** Se calcula dividiendo los nodos frecuentes entre la expresión: $2^d-1 = 31(nodos)$. Teniendo:
#
# $\frac{Nodos Frecuentes}{Total Nodos - 1} = \frac{14}{31}=45.16$%

# %% [markdown]
# ## ***c) ¿Cuál es el radio de poda en este conjunto de datos? (El radio de poda es definido como el porcentaje de conjuntos de items no considerados a ser candidatos, ya sea por que no son generados durante la etapa de generación de candidatos, o por que son podados en la etapa de poda).***
#
# ***RESPUESTA:*** Se calcula dividiendo la suma de los nodos no frecuentes y los no candidatos, entre la expresión: $2^d-1 = 31(nodos)$. Teniendo:
#
# $\frac{Nodos No Frecuentes + Nodos No Candidatos}{Total Nodos - 1} = \frac{17}{31}=54.83$%

# %% [markdown]
# ## ***d) ¿Cuál es la rata de falsa alarma? (porcentaje de los conjuntos de items candidatos que son encontrados NO frecuentes después de calcular el soporte).***
#
# ***RESPUESTA:***
#
# $\frac{Nodos No Frecuentes LuegodeSoporte}{Total Nodos - 1} = \frac{5}{31}=16.13$%

# %% [markdown]
# # ***6. Dada la siguiente base de datos transaccional Y:***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Usar Apriori y FP-Growth para encontrar los conjuntos de ítems frecuentes con mínimo soporte de 2. Tratar con varios
# valores de confianza. Ordenar los conjuntos resultados y analizar resultados de cada algoritmo. Comparar eficiencia de los dos procesos de mineria. Repetir con soporte de 3 y comparar los resultados.

# %% [markdown]
# ***RESPUESTA***
#
# Las pruebas con mínimos soportes de $2 \approx17\%$ y $3 \approx25\%$ se realizaron en tres instancias para cada uno en términos de la confianza para las reglas de asociación ($90\%$, $80\%$ y $70\%$).
#
#
#
# *   Con mínimo soporte de soporte de $17\%$ con algoritmo ***Apriori*** arroja más reglas de asociación, mostrando todas las posibilidades por cada nivel de confianza alcanzado. Por otra parte, el algoritmo ***FP-Growth*** muestra tan solo muestra las reglas con más frecuencia en el dataset.
# *   Con mínimo soporte de soporte de $25\%$ el algoritmo ***Apriori*** y el algoritmo ***FP-Growth*** tienen un comportamiento idéntico, generando las mismas reglas de asociación.
#
# En general, se podría decir que el algoritmo ***FP-Growth*** tiene una mejor eficiencia computacional que el algoritmo ***Apriori*** cuando se tienen mínimos soportes bajos. Esta eficiencia también se visualiza en el número de reglas, ya que ***FP-Growth*** solo muestra las reglas más frecuentes por cada nivel de confianza alcanzado, es decir las mejores reglas posibles.

# %% [markdown]
# **APRIORI**                ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////                 **FP-Growth**
#
# Mínimo soporte: $2 \approx 17\%$
#
# Mínima confianza: $90\%$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **APRIORI**                ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////                 **FP-Growth**
#
# Mínimo soporte: $2 \approx 17\%$
#
# Mínima confianza: $80\%$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **APRIORI**                ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////                 **FP-Growth**
#
# Mínimo soporte: $2 \approx 17\%$
#
# Mínima confianza: $70\%$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **APRIORI**                ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////                 **FP-Growth**
#
# Mínimo soporte: $3 \approx 25\%$
#
# Mínima confianza: $90\%$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **APRIORI**                ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////                 **FP-Growth**
#
# Mínimo soporte: $3 \approx 25\%$
#
# Mínima confianza: $80\%$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **APRIORI**                ////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////                 **FP-Growth**
#
# Mínimo soporte: $3 \approx 25\%$
#
# Mínima confianza: $70\%$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***7. Usando el conjunto de datos del punto 5***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***a) Realizar la tabla de contingencia para las siguientes reglas: b→c , a→d , b→d , e→c , c→a***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ***b) Usar las tablas de contigencia del punto anterior para computar y “realizar un ranking” de las reglas usando:***
#
# **i.** soporte
#
# **ii.** confianza
#
# **iii.** lift

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***8. Importar el conjunto de datos marketBasquet.csv. Extraer reglas de asociación utilizando diferentes valores mínimos de confíanza. Analice los resultados. Reporte los itemsets frecuentes con sus respectivos valores de soporte. Revise los valores de soporte reportados por el operador de itemsets frecuentes. Verifíquelos manualmente. ¿Qué problema se presenta? Extraiga reglas de asociación utilizando diferentes valores mínimos de confíanza. Analice los resultados. Reporte los itemsets frecuentes con sus respectivos valores de soporte. Analice los resultados y discuta las diferencias con el esquema que no posee un filtro de atributos.***
#
# ***Respuesta:*** como se ha observado en puntos anteriores -en diferentes instancias de la confianza- a medida que ésta disminuye, la cantidad de reglas de asociación aumenta. De forma similar al disminuir el soporte.
#
# Se puede ver como el aumento de las reglas de asociación es mayor al disminuir la confianza en comparación con la disminución del soporte. Esto se debe a que es posible generar reglas con baja confianza, pero no ajustar el soporte (número de ocurrencias) en la base de datos transaccional.

# %% [markdown]
# **Itemsets frecuentes. Confianza variante**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $30\%$** --------- **Confianza: $90\%$** --------- **Num. Reglas:** $6$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $30\%$** --------- **Confianza: $75\%$** --------- **Num. Reglas:** $8$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $30\%$** --------- **Confianza: $50\%$** --------- **Num. Reglas:** $22$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $30\%$** --------- **Confianza: $25\%$** --------- **Num. Reglas:** $26$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Itemsets frecuentes. Soporte variante**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $50\%$** --------- **Confianza: $90\%$** --------- **Num. Reglas:** $2$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $25\%$** --------- **Confianza: $90\%$** --------- **Num. Reglas:** $6$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $5\%$** --------- **Confianza: $90\%$** --------- **Num. Reglas:** $12$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***9. Importe el conjunto de datos credit-german.csv (repositorio de machinelearning). Discretice los atributos numéricos en máximo 5 bins de igual tamaño. Aplique el algoritmo de reglas de asociación a este conjunto. Interprete las reglas producidas. Varíe los valores de soporte y de confianza ¿Qué sucede? Interprete las reglas producidas y escoja las que en su concepto son las más interesantes para el problema (justifique).***
#
# ***RESPUESTA:*** al realizar pruebas con distintos valores par el soporte y confianza, se identificaron algunos límites superiores e inferiores para estos dos parámetros. A medida que son menores el soporte y la confianza, más reglas de asociación son encontradas por el algoritmo (*Apriori*), ordenadas a partir de la confianza de manera descendente.
#
# En seguida se listan algunas de las reglas consideradas interesantes.
#
#
#
# *   ***checking_status=no checking other_payment_plans=none 330 ==> class=good 303    conf:(0.92)***
#
# Esta regla considera el soporte y confianza mínimos ($30\%$ y $91\%$ respectivamente) más altos posibles. Se obtiene una confianza de $92\%$ para esta regla, la cual considera el tener una "cuenta bancaria" y "otros planes de pago". Si estos dos atributos son "no checking" y "none", la probabildad de que no tenga riesgos financieros.
#
# *   ***credit_amount='(-inf-3884.8]' other_payment_plans=none job=skilled foreign_worker=yes 391 ==> class=good 300    conf:(0.77)***
#
# En cuanto a riesgos financieros, es importante conocer el endeudamiento de un posible cliente, así como otros planes de pago. Esta regla además, contempla si la persona es un/a trabajor/a extranjero/a. Este último atributo puede ser interesante analizarlo y ver su asociación con otros atributos.
#
# existen muchas otras reglas como se pudo observar con los diferentes soportes y confianzas. sin embargo, son reglas que podrían inferirse en un contexto de riesgos financieros, sin obviar la información de valor que da validar este tipo de reglas con la ayuda de algoritmos para la minería de datos.

# %% [markdown]
# **Se importan los datos al software Weka**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**DISCRETIZACIÓN DE ATRIBUTOS NUMÉRICOS**
# Se aplica el filtro no supervizado *Discretize*, que permite seleccionar el número de bins (5 en este caso) y además son ajustados a un mismo tamaño. En las imagenes se muestra como los atributos numéricos fueron discretizados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: rango [$31\%,100\%$]** --------- **Confianza: rango [$89\%,100\%$]** --------- **Num. Reglas:** no se encontraron reglas de asociaicón.

# %% [markdown]
# **Soporte: $30\%$** --------- **Confianza: $91\%$** --------- **Num. Reglas: $1$**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $30\%$** --------- **Confianza: $50\%$** --------- **Num. Reglas: $162$**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $25\%$** --------- **Confianza: $89\%$** --------- **Num. Reglas: $15$**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soporte: $10\%$** --------- **Confianza: $20\%$** --------- **Num. Reglas: $7507$**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
